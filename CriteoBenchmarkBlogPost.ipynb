# %% [markdown]
# # GraphLab Create v the Criteo Dataset
# ## or, How to Classify 1TB of Clicks using Gradient Boosted Decision Trees

# %% [markdown]
# In June 2014, Criteo Labs have released a [1TB dataset of feature values and click feedback for millions of display
# ads](http://labs.criteo.com/downloads/download-terabyte-click-logs/). The data consists of 24 days of click feedback data. It was soon followed by a [Kaggle competition](https://www.kaggle.com/c/criteo-display-ad-challenge/data).
#
# The Kaggle competition was dedicated to predicting whether a user will click on an ad displayed to her. The data was 7 days of labelled data: 39 features per ad, and the label 1 if the ad was clicked, 0 otherwise. The full criteo dataset contains the data of 24 days, and weighs 1TB in this raw form. This full version is the dataset we are going to tackle today.

# %% [markdown]
# ## The Data
#
# Below are the first 5 rows of the data. As you can see, it has gone through complete anonymization. The first, leftmost column - which we'll denote here as **X1** - is the target column. '1' means a displayed ad was clicked - '0' means it wasn't. Nice-and-binary.
#
# The next 13 columns (**X2-X14**) have numeric, integer values. These are straightforward to use as well. The last 26 columns (**X15-X40**) are categorical.

# %% [markdown]
# <div class="output_subarea output_html rendered_html output_result"><div style="max-height:1000px;max-width:1500px;overflow:auto;"><table frame="box" rules="cols">
#     <tbody><tr>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X1</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X2</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X3</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X4</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X5</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X6</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X7</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X8</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X9</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X10</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X11</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X12</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X13</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X14</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X15</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X16</th>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">110</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">16</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">14</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">7</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">306</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">62770d79</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">e21f5d58</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">32</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">3</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">61</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">3157</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">e5f3fd8d</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">a0aaffa6</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">233</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">146</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">99</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">7</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">3101</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">62770d79</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">ad984203</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">24</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">11</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">24</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">56</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">3</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">2</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">20456</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">None</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top"></td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">710103fd</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">60</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">223</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">15</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">8</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">2</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1582</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">02e197c5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">c2ced437</td>
#     </tr>
# </tbody></table>
# <table frame="box" rules="cols">
#     <tbody><tr>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X17</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X18</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X19</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X20</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X21</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X22</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X23</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X24</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X25</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X26</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X27</th>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">afea442f</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">945c7fcf</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">38b02748</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6fcd6dcb</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">3580aa21</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">28808903</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">46dedfa6</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">2e027dc1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0c7c4231</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">95981d1f</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">00c5ffb7</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6faa15d5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">da8a3421</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">3cd69f23</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6fcd6dcb</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">ab16ed81</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">43426c29</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1df5e154</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">7de9c0a9</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6652dc64</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">99eb4e27</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">00c5ffb7</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">62bec60d</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">386c49ee</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">e755064d</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6fcd6dcb</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">b5f5eb62</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d1f2cc8b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">2e4e821f</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">2e027dc1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0c7c4231</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">12716184</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">00c5ffb7</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">c73d2eb5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">0c758dfb</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">f1738f48</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6fcd6dcb</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">e824fc11</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">09f8a09d</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">e25a4c11</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top"></td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top"></td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">12716184</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d49eb1df</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">a2427619</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">3f85ecae</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">b8c51ab7</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6fcd6dcb</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">26d0f5bb</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">337bf7a5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">e25a4c11</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">6da2367e</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">bf624fa3</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">ec982ce0</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">a77a4a56</td>
#     </tr>
# </tbody></table>
# <table frame="box" rules="cols">
#     <tbody><tr>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X28</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X29</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X30</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X31</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X32</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X33</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X34</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X35</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X36</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X37</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X38</th>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">be4ee537</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">8a0b74cc</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">4cdc3efa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d20856aa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">b8170bba</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">9512c20b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">c38e2f28</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">14f65a5d</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">25b1b089</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d7c1fc0b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">7caf609c</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">be4ee537</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">f3bbfe99</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">4cdc3efa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d20856aa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">a1eb1511</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">9512c20b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">febfd863</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">a3323ca1</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">c8e1ee56</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1752e9e8</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">75350c8a</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">be4ee537</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">f70f0d0b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">4cdc3efa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d20856aa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">628f1b8d</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">9512c20b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">c38e2f28</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">14f65a5d</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">25b1b089</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d7c1fc0b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">34a9b905</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">b96f9e1a</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">2b083b96</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">10dd3744</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">1f7fc70b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">a1eb1511</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">9512c20b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top"></td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top"></td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top"></td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">dc209cd3</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">b8a81fb0</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">be4ee537</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">eb24f585</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">4cdc3efa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d20856aa</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">d9f758ff</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">9512c20b</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">c709ec07</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">2b07677e</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">a89a92a5</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">aa137169</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">e619743b</td>
#     </tr>
# </tbody></table>
# <table frame="box" rules="cols">
#     <tbody><tr>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X39</th>
#         <th style="padding-left: 1em; padding-right: 1em; text-align: center">X40</th>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">30436bfc</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">ed10571d</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">991321ea</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">b757e957</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">ff654802</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">ed10571d</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">30436bfc</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">b757e957</td>
#     </tr>
#     <tr>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">cdc3217e</td>
#         <td style="padding-left: 1em; padding-right: 1em; text-align: center; vertical-align: top">ed10571d</td>
#     </tr>
# </tbody></table>
# [5 rows x 40 columns]<br>
# </div></div>

# %% [markdown]
# ## CountFeaturizer - An Efficient Expansion of Categorical Features
#
# A funny thing about categorical features is that many algorithms have to expand them.
#
# By expansion we mean the following: suppose that this is my dataset:
#
# <table align="left">
#     <tr>
#         <th>categorical_feature_1</th>
#         <th>categorical_feature_2</th>
#         <th>label</th>
#     </tr>
#
#     <tr>
#         <td>a</td>
#         <td>c</td>
#         <td>0</td>
#     </tr>
#
#     <tr>
#         <td>a</td>
#         <td>d</td>
#         <td>0</td>
#     </tr>
#
#     <tr>
#         <td>a</td>
#         <td>a</td>
#         <td>1</td>
#     </tr>
#
#     <tr>
#         <td>b</td>
#         <td>c</td>
#         <td>1</td>
#     </tr>
#
#     <tr>
#         <td>b</td>
#         <td>c</td>
#         <td>0</td>
#     </tr>
#
# </table>

# %% [markdown]
# The first categorical feature can take one of the values **{a, b}**.<br/>
# The second categorical feature can take one of the values **{a, c, d}**.<br/>
#
# Expansion of features means that instead of dealing with 2 features *per-se*, the algorithm will consider each categorical value to be a feature column of it's own, with the value of 1 if the data point (each row in our example) has it, 0 otherwise. You can read more about categorical feature expansion in [Srikrishna's notebook about feature engineering](https://dato.com/learn/gallery/notebooks/feature-engineering.html#Adding-Categorical-Features).
#
# For the purpose of expansion, the same categorical values in different feature columns (such as with value `a`) doesn't mean the algorithm will expand this categorical value into a single column. On the contrary - the expanded dataset will look like this:

# %% [markdown]
# <table align="left">
#     <tr>
#         <th>categorical_feature_1.a</th>
#         <th>categorical_feature_1.b</th>
#         <th>categorical_feature_2.a</th>
#         <th>categorical_feature_2.c</th>
#         <th>categorical_feature_2.d</th>
#         <th>label</th>
#     </tr>
#
#     <tr>
#         <td>1</td>
#         <td>0</td>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0</td>
#         <td>0</td>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#         <td>0</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#         <td>1</td>
#         <td>0</td>
#         <td>0</td>
#     </tr>
#
# </table>

# %% [markdown]
# With only 2 categorical features, one with 2 categories and the other with 3 categories, we suddenly have 5 numerical features. From 2 features to 5 in the most silly example we could produce! What would happen on the full dataset? This is not funny anymore...!
#
# To figure this out, we loaded 1000 rows into an SFrame named `sf1k` and checked the number of category-values using the following code:
#
# ```python
# from collections import Counter
# c = Counter({
#             colname: len(sf1k[colname].unique())
#             for colname in ["X%d" % (i) for i in range(15, 41)]
#     }
# )
# c.most_common()
# ```
#
# We discovered that on the first 1000 rows, 26 categorical features will be expanded into 5537 features!
#
# ```python
# >>> sum(c.itervalues()) # sum of number of unique values per categorical column
# 5537
#
# >>> c.most_common() # distribution of values amongst the columns
# [('X17', 607),
#  ('X26', 584),
#  ('X38', 530),
#  ('X21', 512),
#  ('X16', 388),
#  ('X29', 308),
#  ('X34', 307),
#  ('X15', 307),
#  ('X36', 300),
#  ('X24', 295),
#  ('X35', 267),
#  ('X19', 254),
#  ('X25', 218),
#  ('X18', 182),
#  ('X22', 181),
#  ('X37', 121),
#  ('X32', 47),
#  ('X28', 46),
#  ('X40', 17),
#  ('X23', 14),
#  ('X39', 13),
#  ('X33', 12),
#  ('X30', 12),
#  ('X27', 9),
#  ('X31', 4),
#  ('X20', 2)]
# ```

# %% [markdown]
# In the context of Gradient Boosted Trees, each categorical value may have its own node in the tree.
#
# While GraphLab can handle this situation, this is a very heavy-duty task, when there's another way to represent these categorical values. In the benchmark notebook, we will run build a model using only those categorical feature columns with as little categorical values as possible.

# %% [markdown]
# The other way is to use our [Count Featurizer](https://dato.com/products/create/docs/generated/graphlab.toolkits.feature_engineering.CountFeaturizer.html#graphlab.toolkits.feature_engineering.CountFeaturizer),
# which implements the method described here:
# [https://blogs.technet.microsoft.com/machinelearning/2015/02/17/big-learning-made-easy-with-counts/](https://blogs.technet.microsoft.com/machinelearning/2015/02/17/big-learning-made-easy-with-counts/).
#
# You will see this in practice in the benchmark notebook, and you're invited to [read more about in in our API documentation](https://dato.com/products/create/docs/generated/graphlab.toolkits.feature_engineering.CountFeaturizer.html#graphlab.toolkits.feature_engineering.CountFeaturizer).

# %% [markdown]
# ## Tweaking Runtime Configuration
#
# Inspecting the code, you will see that before all the data loading, models training and fine tuning, there are two changes to the runtime config:
# ```python
# gl.set_runtime_config('GRAPHLAB_FILEIO_MAXIMUM_CACHE_CAPACITY', 20 * 1024 * 1024 * 1024)
# gl.set_runtime_config('GRAPHLAB_FILEIO_MAXIMUM_CACHE_CAPACITY_PER_FILE', 20 * 1024 * 1024 * 1024)
# ```
#
# When dealing with extremely large datasets, on an amazingly powerful machine, such tweaks can save a lot of time.
#
# **MAXIMUM_CACHE_CAPACITY** is the number of bytes to hold in memory before flushing to disk. SFrame/SArray are all "external memory" datastructures, but we don't want to flush any SFrame/SArray objects to disk. So we have a cache io layer acting as a disk buffer, and the constant is the capacity of the buffer. Once the size of new intermediate SFrame/SArray exceeds the buffer, they are flushed to disk.
#
# **MAXIMUM_CACHE_CAPACITY_PER_FILE** is similar to **MAXIMUM_CACHE_CAPACITY** but limit to a single file.
#
# The goal of these changes is to improve the disk IO efficiency because the boosted trees model is running external memory mode. Before the first iteration, we preprocess and sort the columns and save on disk. Each iteration at every depth, these "columns" are loaded into memory to search the best split.

# %% [markdown]
# ## A note about using a Validation Set in GraphLab Create
#
# You might notice that during model creation (AKA training), the `create()` method is supplied with the test split as its `validation set`:
#
# ```python
# model = gl.boosted_trees_classifier.create(full_train,
#                                                target=target_feature,
#                                                validation_set=test,
#                                                features=(num_features + cat_features),
#                                                max_iterations=5,
#                                                random_seed=0)
# ```
#
# Are we using test data during training? Are we breaking one of the ground rules of machine learning?
#
# Rest assured - we aren't doing that. Supplying a validation set is equivalent to running `model.evaludate(validation_set)` after each iteration of the algorithm. It does not affect the training process, the direction of the gradients, etc. For our purposes, this is only done to track the progress of the algorithm and see how each iteration affects the final accuracy (as the validation accuracy is really the test accuracy).
#
# With some algorithms, a validation set can be useful though, even to the point that GraphLab would take out 5% of the supplied train data to be used as the validation set. If the algorithm implements an early-stopping option, it can stop training if there is no significant improvement in the validation metrics after some iterations. This option is available for boosted trees but is turned off by default.
#
# For more information, read the documentation for the **early_stopping_rounds** parameter in the [boosted trees API documentation](https://dato.com/products/create/docs/generated/graphlab.boosted_trees_classifier.create.html#graphlab.boosted_trees_classifier.create).
